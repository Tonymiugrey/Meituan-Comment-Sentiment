# %% [markdown]
# # Model Deploying and Testing

# %% [markdown]
# ## Dependencies

# %%
from Core import *

# %% [markdown]
# ## 模型选择
# LR模型：过采样数据集训练所得
#
# BERT模型：Exist/Food使用过采样，其他均为正常数据集训练所得

# %% [markdown]
# ## 预测

# %%
text = "4点半领的号，快8点才排到队能吃上饭，真是满满的泪本来想点明虾煲，可是太迟了，没有啦中秋节吃个饭好辛苦的= =最后点了大份肉蟹煲，料挺足的，有青蟹、鸡爪、年糕、土豆~不过青蟹挺瘦的，然后吃到最后只感觉到咸了= =鸡爪好好吃的，酥酥软软，超级容易吐骨头！！但是同去的两个妹子说对鸡爪有阴影，不肯吃！！真是缺少了品味这一人间美味的绝佳体验机会啊(￣∇￣)~然后就被我们剩下俩人承包啦，吃得超级饱哈。这里最后要吐槽下服务，真是…服务员动作都好不利索的，因为始终没见人过来，我自己过去打算把点好的菜单给她们，结果被吐槽说要回位子上她们会过来的= =|||我都坐下半天了都不见人过来好不好…建立店家每个分区分派人手啊，不然这么慢的点菜速度，会让客人饿呆的= ="

# %%
# LR
print(text)
Predict(text, type='lr') # type: 'lr'/'bert'，默认bert; v: 展示特征分析，默认false
# 关于是否显著：当前阈值0.5， 感觉需要高一些
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\miuGrey\AppData\Local\Temp\jieba.cache
# 4点半领的号，快8点才排到队能吃上饭，真是满满的泪本来想点明虾煲，可是太迟了，没有啦中秋节吃个饭好辛苦的= =最后点了大份肉蟹煲，料挺足的，有青蟹、鸡爪、年糕、土豆~不过青蟹挺瘦的，然后吃到最后只感觉到咸了= =鸡爪好好吃的，酥酥软软，超级容易吐骨头！！但是同去的两个妹子说对鸡爪有阴影，不肯吃！！真是缺少了品味这一人间美味的绝佳体验机会啊(￣∇￣)~然后就被我们剩下俩人承包啦，吃得超级饱哈。这里最后要吐槽下服务，真是…服务员动作都好不利索的，因为始终没见人过来，我自己过去打算把点好的菜单给她们，结果被吐槽说要回位子上她们会过来的= =|||我都坐下半天了都不见人过来好不好…建立店家每个分区分派人手啊，不然这么慢的点菜速度，会让客人饿呆的= =
# 加载LR模型
# Loading model cost 0.593 seconds.
# Prefix dict has been built successfully.
# <style type="text/css">
# </style>
# <table id="T_bfcfc">
#   <caption>评论文本情感</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfcfc_level0_col0" class="col_heading level0 col0" >情感</th>
#       <th id="T_bfcfc_level0_col1" class="col_heading level0 col1" >概率</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfcfc_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
print(text)
Predict(text)
# Out:
# 4点半领的号，快8点才排到队能吃上饭，真是满满的泪本来想点明虾煲，可是太迟了，没有啦中秋节吃个饭好辛苦的= =最后点了大份肉蟹煲，料挺足的，有青蟹、鸡爪、年糕、土豆~不过青蟹挺瘦的，然后吃到最后只感觉到咸了= =鸡爪好好吃的，酥酥软软，超级容易吐骨头！！但是同去的两个妹子说对鸡爪有阴影，不肯吃！！真是缺少了品味这一人间美味的绝佳体验机会啊(￣∇￣)~然后就被我们剩下俩人承包啦，吃得超级饱哈。这里最后要吐槽下服务，真是…服务员动作都好不利索的，因为始终没见人过来，我自己过去打算把点好的菜单给她们，结果被吐槽说要回位子上她们会过来的= =|||我都坐下半天了都不见人过来好不好…建立店家每个分区分派人手啊，不然这么慢的点菜速度，会让客人饿呆的= =
# 加载BERT模型
# <style type="text/css">
# </style>
# <table id="T_06a32">
#   <caption>评论文本情感</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06a32_level0_col0" class="col_heading level0 col0" >情感</th>
#       <th id="T_06a32_level0_col1" class="col_heading level0 col1" >概率</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06a32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06a32_row0_col0" class="data row0 col0" >积极</td>
#       <td id="T_06a32_row0_col1" class="data row0 col1" >0.967339</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# ...

# %%
# bert
print(text)
Predict(text, v=True)
# Out:
# 4点半领的号，快8点才排到队能吃上饭，真是满满的泪本来想点明虾煲，可是太迟了，没有啦中秋节吃个饭好辛苦的= =最后点了大份肉蟹煲，料挺足的，有青蟹、鸡爪、年糕、土豆~不过青蟹挺瘦的，然后吃到最后只感觉到咸了= =鸡爪好好吃的，酥酥软软，超级容易吐骨头！！但是同去的两个妹子说对鸡爪有阴影，不肯吃！！真是缺少了品味这一人间美味的绝佳体验机会啊(￣∇￣)~然后就被我们剩下俩人承包啦，吃得超级饱哈。这里最后要吐槽下服务，真是…服务员动作都好不利索的，因为始终没见人过来，我自己过去打算把点好的菜单给她们，结果被吐槽说要回位子上她们会过来的= =|||我都坐下半天了都不见人过来好不好…建立店家每个分区分派人手啊，不然这么慢的点菜速度，会让客人饿呆的= =
# 加载BERT模型
# <style type="text/css">
# </style>
# <table id="T_ddecf">
#   <caption>评论文本情感</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddecf_level0_col0" class="col_heading level0 col0" >情感</th>
#       <th id="T_ddecf_level0_col1" class="col_heading level0 col1" >概率</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddecf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ddecf_row0_col0" class="data row0 col0" >积极</td>
#       <td id="T_ddecf_row0_col1" class="data row0 col1" >0.967339</td>
#     </tr>
#   </tbody>
# </table>
#     <style>
# ...
